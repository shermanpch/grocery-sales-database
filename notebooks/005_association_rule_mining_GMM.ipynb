# %%
import os
from pathlib import Path


# Navigate to the project root directory (where .git is)
def find_git_root(path="."):
    path = Path(path).resolve()
    for parent in [path] + list(path.parents):
        if (parent / ".git").exists():
            return parent
    return path  # fallback if .git not found


project_root = find_git_root()
os.chdir(project_root)
print(f"Working directory set to: {project_root}")
# Out:
# Working directory set to: /Users/sherman/GitHub/ISYE-6740/Final Project/Workspace

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mlxtend.frequent_patterns import association_rules, fpgrowth
from mlxtend.preprocessing import TransactionEncoder

pd.set_option("display.max_columns", 50)

# %%
transaction_data = pd.read_parquet(
    "data/processed/master_dataset.parquet",
    columns=["CustomerID", "ProductName", "CategoryName", "Class"],
)

cluster_data = pd.read_parquet("data/processed/clustered_customer_gmm.parquet")

display(transaction_data.head())
print(f"Transaction data shape: {transaction_data.shape}")

display(cluster_data.head())
print(f"Cluster data shape: {cluster_data.shape}")
# Out:
#    CustomerID                 ProductName CategoryName   Class
# 0       27039            Vaccum Bag 10x13  Confections    High
# 1       25011                    Sardines        Grain     Low
# 2       94024     Crab - Imitation Flakes      Produce  Medium
# 3       73966  Smirnoff Green Apple Twist      Seafood    High
# 4       32653         Coffee - Dark Roast      Poultry     Low
# Transaction data shape: (6758125, 4)
#   CustomerID  cluster_label
# 0          1              2
# 1          2              2
# 2          3              2
# 3          4              2
# 4          5              2
# Cluster data shape: (98759, 2)

# %%
transaction_data["CustomerID"] = transaction_data["CustomerID"].astype(str)
cluster_data["CustomerID"] = cluster_data["CustomerID"].astype(str)

# %%
df = pd.merge(
    transaction_data,
    cluster_data,
    on="CustomerID",
    how="left",
    validate="m:1",
)

df.head()
# Out:
#   CustomerID                 ProductName CategoryName   Class  cluster_label
# 0      27039            Vaccum Bag 10x13  Confections    High              1
# 1      25011                    Sardines        Grain     Low              1
# 2      94024     Crab - Imitation Flakes      Produce  Medium              2
# 3      73966  Smirnoff Green Apple Twist      Seafood    High              2
# 4      32653         Coffee - Dark Roast      Poultry     Low              1

# %%
# Set a reproducible random state
RANDOM_STATE = 42

# %%
# Container for rules per cluster
cluster_rules = {}

# Loop through each unique cluster
for cluster_id in df["cluster_label"].unique():
    print(f"\n Processing Cluster: {cluster_id}")

    # Filter data for this cluster
    cluster_df = df[df["cluster_label"] == cluster_id]

    sampled_customers = (
        cluster_df["CustomerID"]
        .drop_duplicates()
        .sample(n=3500, random_state=RANDOM_STATE)
    )

    sampled_df = cluster_df[cluster_df["CustomerID"].isin(sampled_customers)]

    # Create basket: group by CustomerID → list of ProductNames
    baskets = sampled_df.groupby("CustomerID")["ProductName"].apply(list).tolist()

    # One-hot encode
    te = TransactionEncoder()
    te_matrix = te.fit(baskets).transform(baskets)
    df_encoded = pd.DataFrame(te_matrix, columns=te.columns_)

    # Find frequent itemsets
    frequent_items = fpgrowth(
        df_encoded,
        use_colnames=True,
        min_support=0.02,
    )

    # Generate association rules
    rules = association_rules(frequent_items, metric="lift", min_threshold=1)
    rules["cluster"] = cluster_id

    cluster_rules[cluster_id] = rules
# Out:
#  Processing Cluster: 1
#
#  Processing Cluster: 2
#
#  Processing Cluster: 3
#
#  Processing Cluster: 0

# %%
result_rules = (
    pd.concat(cluster_rules.values(), ignore_index=True)
    .sort_values(by=["lift", "confidence", "cluster"], ascending=[False, False, True])
    .reset_index(drop=True)
)

result_rules["antecedents"] = result_rules["antecedents"].apply(list)
result_rules["consequents"] = result_rules["consequents"].apply(list)

result_rules
# Out:
#                               antecedents                         consequents  \
# 0                               [Papayas]       [Pepper - Paprika, Hungarian]
# 1           [Pepper - Paprika, Hungarian]                           [Papayas]
# 2       [Soup - Campbells Tomato Ravioli]       [Pork - Bacon, Double Smoked]
# 3           [Pork - Bacon, Double Smoked]   [Soup - Campbells Tomato Ravioli]
# 4                          [Flour - Teff]             [Pop Shoppe Cream Soda]
# ...                                   ...                                 ...
# 271261                    [Pate - Cognac]  [Beef - Ground, Extra Lean, Fresh]
# 271262        [Macaroons - Two Bite Choc]          [Cheese - Parmesan Grated]
# 271263       [Wine - Sogrape Mateus Rose]                   [Garlic - Peeled]
# 271264                [Crackers Cheez It]              [Beef - Prime Rib Aaa]
# 271265                    [Peas - Frozen]                   [Fondant - Icing]
#
#         antecedent support  consequent support   support  confidence  \
# 0                 0.121143            0.124571  0.023714    0.195755
# 1                 0.124571            0.121143  0.023714    0.190367
# 2                 0.134286            0.139143  0.028857    0.214894
# 3                 0.139143            0.134286  0.028857    0.207392
# 4                 0.121143            0.122286  0.022571    0.186321
# ...                    ...                 ...       ...         ...
# 271261            0.142857            0.140000  0.020000    0.140000
# 271262            0.142857            0.140000  0.020000    0.140000
# 271263            0.142857            0.140000  0.020000    0.140000
# 271264            0.150000            0.137143  0.020571    0.137143
# 271265            0.150000            0.137143  0.020571    0.137143
#
#             lift  representativity  leverage  conviction  zhangs_metric  \
# 0       1.571425               1.0  0.008623    1.088509       0.413759
# 1       1.571425               1.0  0.008623    1.085501       0.415380
# 2       1.544410               1.0  0.010172    1.096485       0.407182
# 3       1.544410               1.0  0.010172    1.092235       0.409480
# 4       1.523651               1.0  0.007757    1.078698       0.391055
# ...          ...               ...       ...         ...            ...
# 271261  1.000000               1.0  0.000000    1.000000       0.000000
# 271262  1.000000               1.0  0.000000    1.000000       0.000000
# 271263  1.000000               1.0  0.000000    1.000000       0.000000
# 271264  1.000000               1.0  0.000000    1.000000       0.000000
# 271265  1.000000               1.0  0.000000    1.000000       0.000000
#
#          jaccard  certainty  kulczynski  cluster
# 0       0.106821   0.081313    0.193061        0
# 1       0.106821   0.078766    0.193061        0
# 2       0.117991   0.087995    0.211143        2
# 3       0.117991   0.084446    0.211143        2
# 4       0.102199   0.072957    0.185450        0
# ...          ...        ...         ...      ...
# 271261  0.076087   0.000000    0.141429        2
# 271262  0.076087   0.000000    0.141429        3
# 271263  0.076087   0.000000    0.141429        3
# 271264  0.077170   0.000000    0.143571        2
# 271265  0.077170   0.000000    0.143571        2
#
# [271266 rows x 15 columns]

# %%
result_rules.to_parquet("data/processed/association_rules_gmm.parquet", index=False)
result_rules = pd.read_parquet("data/processed/association_rules_gmm.parquet")

# %% [markdown]
# # Top Rules Per Cluster (By Lift)

# %%
# Top 20 rules per cluster by lift
top_rules_by_lift = (
    result_rules.sort_values(by=["cluster", "lift"], ascending=[True, False])
    .groupby("cluster")
    .head(10)
    .reset_index(drop=True)
)

top_rules_by_lift["antecedents"] = top_rules_by_lift["antecedents"].apply(
    lambda x: ", ".join(list(x))
)

top_rules_by_lift["consequents"] = top_rules_by_lift["consequents"].apply(
    lambda x: ", ".join(list(x))
)

top_rules_by_lift = pd.merge(
    top_rules_by_lift,
    df[["ProductName", "CategoryName", "Class"]]
    .drop_duplicates()
    .rename(
        columns={
            "ProductName": "antecedents",
            "CategoryName": "antecedents_category",
            "Class": "antecedents_class",
        }
    ),
    on="antecedents",
    how="left",
)

top_rules_by_lift = pd.merge(
    top_rules_by_lift,
    df[["ProductName", "CategoryName", "Class"]]
    .drop_duplicates()
    .rename(
        columns={
            "ProductName": "consequents",
            "CategoryName": "consequents_category",
            "Class": "consequents_class",
        }
    ),
    on="consequents",
    how="left",
)

top_rules_by_lift[
    [
        "cluster",
        "antecedents",
        "antecedents_category",
        "antecedents_class",
        "consequents",
        "consequents_category",
        "consequents_class",
        "support",
        "confidence",
        "lift",
    ]
]
# Out:
#     cluster                        antecedents antecedents_category  \
# 0         0                            Papayas           Shell fish
# 1         0        Pepper - Paprika, Hungarian           Shell fish
# 2         0                       Flour - Teff                Dairy
# 3         0              Pop Shoppe Cream Soda                Dairy
# 4         0                Beets - Mini Golden           Shell fish
# 5         0               Coffee - Irish Cream           Shell fish
# 6         0      Bread Crumbs - Japanese Style              Seafood
# 7         0           Wine - Fume Blanc Fetzer              Seafood
# 8         0                             Pernod               Snails
# 9         0  Pasta - Cheese / Spinach Bauletti               Snails
# 10        1           Snapple - Iced Tea Peach            Beverages
# 11        1                    Fondant - Icing              Poultry
# 12        1                     Black Currants              Poultry
# 13        1             Muffin Batt - Choc Chk              Produce
# 14        1             Cake - Mini Cheesecake              Poultry
# 15        1                   Olives - Stuffed            Beverages
# 16        1                Veal - Eye Of Round                 Meat
# 17        1                   Mussels - Frozen               Snails
# 18        1      Wine - Vidal Icewine Magnotta              Cereals
# 19        1          Ecolab - Mikroklene 4/4 L          Confections
# 20        2    Soup - Campbells Tomato Ravioli          Confections
# 21        2        Pork - Bacon, Double Smoked              Seafood
# 22        2                       Sherry - Dry            Beverages
# 23        2        Wine - Cahors Ac 2000, Clos              Produce
# 24        2                    Crackers - Trio              Seafood
# 25        2                   Lettuce - Frisee              Seafood
# 26        2       Veal - Brisket, Provimi,bnls                 Meat
# 27        2   Beef - Ground, Extra Lean, Fresh              Cereals
# 28        2               Beef - Prime Rib Aaa           Shell fish
# 29        2        Pastry - Butterscotch Baked               Snails
# 30        3                  Veal - Osso Bucco                Grain
# 31        3              Oregano - Dry, Rubbed              Produce
# 32        3                     Mustard - Seed            Beverages
# 33        3          Anchovy Paste - 56 G Tube              Cereals
# 34        3                         Dried Figs              Produce
# 35        3                            Mangoes          Confections
# 36        3            Bandage - Flexible Neon                Dairy
# 37        3          Orange - Canned, Mandarin              Produce
# 38        3  Beer - Alexander Kieths, Pale Ale              Cereals
# 39        3               Sun - Dried Tomatoes              Seafood
#
#    antecedents_class                        consequents consequents_category  \
# 0                Low        Pepper - Paprika, Hungarian           Shell fish
# 1             Medium                            Papayas           Shell fish
# 2                Low              Pop Shoppe Cream Soda                Dairy
# 3             Medium                       Flour - Teff                Dairy
# 4             Medium               Coffee - Irish Cream           Shell fish
# 5             Medium                Beets - Mini Golden           Shell fish
# 6                Low           Wine - Fume Blanc Fetzer              Seafood
# 7                Low      Bread Crumbs - Japanese Style              Seafood
# 8               High  Pasta - Cheese / Spinach Bauletti               Snails
# 9                Low                             Pernod               Snails
# 10              High                    Fondant - Icing              Poultry
# 11              High           Snapple - Iced Tea Peach            Beverages
# 12              High             Muffin Batt - Choc Chk              Produce
# 13            Medium                     Black Currants              Poultry
# 14               Low                   Olives - Stuffed            Beverages
# 15               Low             Cake - Mini Cheesecake              Poultry
# 16              High                   Mussels - Frozen               Snails
# 17              High                Veal - Eye Of Round                 Meat
# 18               Low          Ecolab - Mikroklene 4/4 L          Confections
# 19            Medium      Wine - Vidal Icewine Magnotta              Cereals
# 20               Low        Pork - Bacon, Double Smoked              Seafood
# 21            Medium    Soup - Campbells Tomato Ravioli          Confections
# 22              High        Wine - Cahors Ac 2000, Clos              Produce
# 23            Medium                       Sherry - Dry            Beverages
# 24               Low                   Lettuce - Frisee              Seafood
# 25            Medium                    Crackers - Trio              Seafood
# 26              High   Beef - Ground, Extra Lean, Fresh              Cereals
# 27            Medium       Veal - Brisket, Provimi,bnls                 Meat
# 28               Low        Pastry - Butterscotch Baked               Snails
# 29              High               Beef - Prime Rib Aaa           Shell fish
# 30              High              Oregano - Dry, Rubbed              Produce
# 31              High                  Veal - Osso Bucco                Grain
# 32               Low          Anchovy Paste - 56 G Tube              Cereals
# 33            Medium                     Mustard - Seed            Beverages
# 34            Medium                            Mangoes          Confections
# 35            Medium                         Dried Figs              Produce
# 36            Medium          Orange - Canned, Mandarin              Produce
# 37               Low            Bandage - Flexible Neon                Dairy
# 38            Medium               Sun - Dried Tomatoes              Seafood
# 39            Medium  Beer - Alexander Kieths, Pale Ale              Cereals
#
#    consequents_class   support  confidence      lift
# 0             Medium  0.023714    0.195755  1.571425
# 1                Low  0.023714    0.190367  1.571425
# 2             Medium  0.022571    0.186321  1.523651
# 3                Low  0.022571    0.184579  1.523651
# 4             Medium  0.027429    0.197531  1.522815
# 5             Medium  0.027429    0.211454  1.522815
# 6                Low  0.022571    0.186761  1.499230
# 7                Low  0.022571    0.181193  1.499230
# 8                Low  0.025429    0.192641  1.488394
# 9               High  0.025429    0.196468  1.488394
# 10              High  0.027143    0.201699  1.452561
# 11              High  0.027143    0.195473  1.452561
# 12            Medium  0.026286    0.179688  1.445761
# 13              High  0.026286    0.211494  1.445761
# 14               Low  0.027714    0.202083  1.443452
# 15               Low  0.027714    0.197959  1.443452
# 16              High  0.024857    0.176829  1.432645
# 17              High  0.024857    0.201389  1.432645
# 18            Medium  0.028571    0.200000  1.431493
# 19               Low  0.028571    0.204499  1.431493
# 20            Medium  0.028857    0.214894  1.544410
# 21               Low  0.028857    0.207392  1.544410
# 22            Medium  0.030000    0.213849  1.518200
# 23              High  0.030000    0.212982  1.518200
# 24            Medium  0.029429    0.210204  1.477338
# 25               Low  0.029429    0.206827  1.477338
# 26            Medium  0.030857    0.202627  1.447333
# 27              High  0.030857    0.220408  1.447333
# 28              High  0.028000    0.204167  1.446525
# 29               Low  0.028000    0.198381  1.446525
# 30              High  0.030571    0.215292  1.471721
# 31              High  0.030571    0.208984  1.471721
# 32            Medium  0.030000    0.209163  1.435435
# 33               Low  0.030000    0.205882  1.435435
# 34            Medium  0.028286    0.201629  1.434355
# 35            Medium  0.028286    0.201220  1.434355
# 36               Low  0.028286    0.207983  1.432955
# 37            Medium  0.028286    0.194882  1.432955
# 38            Medium  0.024571    0.187364  1.428700
# 39            Medium  0.024571    0.187364  1.428700

# %% [markdown]
# # Proportion of CategoryName per Cluster

# %%
# Prepare data: only consequents_category
category_df = top_rules_by_lift[["cluster", "consequents_category"]]

# Count and normalize
category_counts = (
    category_df.groupby(["cluster", "consequents_category"])
    .size()
    .unstack(fill_value=0)
)

category_props = category_counts.div(category_counts.sum(axis=1), axis=0)

# Plot
category_props.plot(kind="bar", stacked=True, figsize=(12, 6), colormap="tab20")
plt.title("Consequent CategoryName per Cluster")
plt.ylabel("Proportion")
plt.xlabel("Cluster")
plt.legend(title="CategoryName", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Proportion of Class per Cluster

# %%
# Prepare data: only consequents_class
class_df = top_rules_by_lift[["cluster", "consequents_class"]]

# Count and normalize
class_counts = (
    class_df.groupby(["cluster", "consequents_class"]).size().unstack(fill_value=0)
)
class_props = class_counts.div(class_counts.sum(axis=1), axis=0)

# Plot
class_props.plot(kind="bar", stacked=True, figsize=(10, 5), colormap="tab10")
plt.title("Consequent Class per Cluster")
plt.ylabel("Proportion")
plt.xlabel("Cluster")
plt.legend(title="Class", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution of Rule Strength (Confidence & Lift)

# %%
# Boxplot for confidence
plt.figure(figsize=(10, 5))
sns.boxplot(data=result_rules, x="cluster", y="confidence")
plt.title("Distribution of Confidence per Cluster")
plt.show()

# Boxplot for lift
plt.figure(figsize=(10, 5))
sns.boxplot(data=result_rules, x="cluster", y="lift")
plt.title("Distribution of Lift per Cluster")
plt.show()

# %% [markdown]
# # Most Common Consequents Per Cluster

# %%
# Convert frozensets to strings for readability
result_rules["consequents_str"] = result_rules["consequents"].apply(
    lambda x: ", ".join(list(x))
)

top_consequents = (
    result_rules.groupby(["cluster", "consequents_str"])
    .size()
    .reset_index(name="count")
    .sort_values(["cluster", "count"], ascending=[True, False])
    .groupby("cluster")
    .head(5)
    .reset_index(drop=True)
)

top_consequents
# Out:
#     cluster                consequents_str  count
# 0         0  Soup - Campbells, Beef Barley    203
# 1         0        Yogurt - French Vanilla    188
# 2         0                  Pork - Kidney    186
# 3         0                        Campari    182
# 4         0                Grouper - Fresh    179
# 5         1                   Pears - Bosc    238
# 6         1              Veal - Osso Bucco    227
# 7         1    Cheese - Victor Et Berthold    226
# 8         1           Thyme - Lemon, Fresh    226
# 9         1   Nantucket - Pomegranate Pear    225
# 10        2  Bar Mix - Pina Colada, 355 Ml    245
# 11        2                  Sauce - Rosee    242
# 12        2                    Wanton Wrap    241
# 13        2        Table Cloth 54x72 White    240
# 14        2              Apricots - Halves    239
# 15        3      Ice Cream Bar - Drumstick    239
# 16        3      Ice Cream Bar - Oreo Cone    239
# 17        3                     Barramundi    238
# 18        3     Lemonade - Natural, 591 Ml    238
# 19        3           Pecan Raisin - Tarts    238

# %% [markdown]
# # Top Antecedents Per Cluster

# %%
result_rules["antecedents_str"] = result_rules["antecedents"].apply(
    lambda x: ", ".join(list(x))
)

top_antecedents = (
    result_rules.groupby(["cluster", "antecedents_str"])
    .size()
    .reset_index(name="count")
    .sort_values(["cluster", "count"], ascending=[True, False])
    .groupby("cluster")
    .head(5)
    .reset_index(drop=True)
)

top_antecedents
# Out:
#     cluster                antecedents_str  count
# 0         0  Soup - Campbells, Beef Barley    203
# 1         0        Yogurt - French Vanilla    188
# 2         0                  Pork - Kidney    186
# 3         0                        Campari    182
# 4         0                Grouper - Fresh    179
# 5         1                   Pears - Bosc    238
# 6         1              Veal - Osso Bucco    227
# 7         1    Cheese - Victor Et Berthold    226
# 8         1           Thyme - Lemon, Fresh    226
# 9         1   Nantucket - Pomegranate Pear    225
# 10        2  Bar Mix - Pina Colada, 355 Ml    245
# 11        2                  Sauce - Rosee    242
# 12        2                    Wanton Wrap    241
# 13        2        Table Cloth 54x72 White    240
# 14        2              Apricots - Halves    239
# 15        3      Ice Cream Bar - Drumstick    239
# 16        3      Ice Cream Bar - Oreo Cone    239
# 17        3                     Barramundi    238
# 18        3     Lemonade - Natural, 591 Ml    238
# 19        3           Pecan Raisin - Tarts    238

# %% [markdown]
# # Scatter Plot of Confidence vs Lift (Per Cluster)

# %%
sampled_rules = (
    result_rules[(result_rules["confidence"] > 0.15) & (result_rules["lift"] > 1.1)]
    .groupby("cluster")
    .sample(frac=0.05, random_state=42)
)

plt.figure(figsize=(12, 6))
sns.lmplot(
    data=sampled_rules,
    x="confidence",
    y="lift",
    hue="cluster",
    palette="tab10",
    scatter_kws={"alpha": 0.5, "s": 15},
    line_kws={"linewidth": 1},
    height=6,
    aspect=2,
    ci=None,
)

plt.title("Confidence vs Lift (Per Cluster) with Regression Lines")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Number of Rules per Cluster

# %%
rules_per_cluster = result_rules["cluster"].value_counts().sort_index()
rules_per_cluster.plot(kind="bar", figsize=(8, 4), title="Number of Rules per Cluster")
# Out:
# <Axes: title={'center': 'Number of Rules per Cluster'}, xlabel='cluster'>

# %% [markdown]
# # Summary Table per Cluster

# %%
summary = (
    result_rules.groupby("cluster")
    .agg(
        num_rules=("antecedents", "count"),
        avg_confidence=("confidence", "mean"),
        avg_lift=("lift", "mean"),
        max_lift=("lift", "max"),
        max_confidence=("confidence", "max"),
    )
    .reset_index()
)

summary
# Out:
#    cluster  num_rules  avg_confidence  avg_lift  max_lift  max_confidence
# 0        0      31270        0.155835  1.136387  1.571425        0.214953
# 1        1      62014        0.154510  1.109832  1.452561        0.211494
# 2        2      88666        0.156332  1.088441  1.544410        0.293307
# 3        3      89316        0.155710  1.086786  1.471721        0.215292
